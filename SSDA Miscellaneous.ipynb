# %%
master = open("ESSSS_master_list.txt","r")

# %%
brazil = open("Brazil Files.txt","w")

# %%
images = open("Images.txt","w")

# %%
for line in master:
    if (line.rfind(".") == len(line) - 5) or (line.rfind(".") == len(line) - 4):
        images.write(line)

# %%
md5 = 0
md5check = open("Images.txt","r")
for line in md5check:
    extension = line[line.rfind(".") + 1:]
    if "JPG" in extension:
        md5 += 1  
print(md5)
# Out:
# 188427

# %%
md5check = open("Images.txt","r")
files = 0
for line in md5check:
    files += 1
print(files)
# Out:
# 844326

# %%
md5check.close()
images.close()

# %%
clean = open("Clean Master","w")
for line in master:
    clean.write(line)

# %%
clean.close()

# %%
master = open("ESSSS_master_list.txt","r")
clean = open("Clean Master.txt","w")
for line in master:
    clean.write(line)

# %%
count = open("Clean Master.txt","r")
c = 0
for line in count:
    c += 1
print(c)
# Out:
# 905858

# %%
test = open("LenRfind.txt","w")
count = open("Clean Master.txt","r")
for line in count:
    test.write(str(len(line)) + " " + str(line.rfind(".")) + "\n")

# %%
files = 0
count.close()
mr = open("Clean Master.txt","r")
for line in mr:
    if line.rfind(".") == len(line) - 5:
        files += 1
print(files)
# Out:
# 843608

# %%
test.close()

# %%
mr = open("Clean Master.txt","r")
md5 = 0
for file in mr:
    if file[len(file) - 4:len(file) - 1] == "md5":
        md5 += 1
print(md5)
# Out:
# 75010

# %%
ext = open("Ext.txt","w")
mr = open("Clean Master.txt","r")
for file in mr:
    ext.write(file[len(file) - 4:len(file) - 2])

# %%
ext.close()

# %%
mr = open("Clean Master.txt","r")
im = open("Images.txt","w")
for file in mr:
    if file[len(file) - 4:len(file) - 1] != "md5" and file.rfind(".") == len(file) - 5:
        im.write(file)

# %%
ine = open("ImNoExt.txt","w")
brazil.close()

# %%
im.close()
im = open("Images.txt","r")
for file in im:
    ine.write(file[:file.rfind(".")] + "\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-5eb642876e69> in <module>()
#       2 im = open("Images.txt","r")
#       3 for file in im:
# ----> 4     ine.write(file[:file.rfind(".")] + "\n")
#
# ValueError: I/O operation on closed file.

# %%
ine.close()

# %%
im = open("Images.txt","r")
ine = open("ImNoExt.txt","w")
for file in im:
    ine.write(file[:file.rfind(".")] + "\n")

# %%
ine.close()
im.close()

# %%
ind = open("ImNoDup.txt","w")
with open('ImNoExt.txt') as f:
    total = 0
    dup = 0
    seen = set()    
    for line in f:
        total += 1
        if not (line in seen):
            ind.write(line)
            seen.add(line)
        else:
            dup += 1
print(total)
print(dup)
# Out:
# 768678
# 152413

# %%
ind.close()
ind = open("ImNoDup.txt","r")
count = 0
for line in ind:
    count += 1
print(count)
print(count + dup)
# Out:
# 616265
# 768678

# %%
ind = open("ImNoDup.txt","r")
angela = 0
eap255 = 0
courtney = 0
c_c = 0
d_l = 0
eakin = 0
eap503 = 0
eap640 = 0
eap853 = 0
oscar = 0
staug = 0
brazil = 0
colombia = 0
cuba = 0
for line in ind:
    if "Angela" in line:
        angela += 1
    elif "Courtney" in line:
        if "EAP255" in line:
            eap255 += 1
        else:
            courtney += 1
    elif "Cuba_Colombia" in line:
        if not ("ESSS CUBA") in line:
            c_c += 1
    elif "David_LaFevor" in line:
        d_l += 1
    elif "Eakin" in line:
        eakin += 1
    elif "EAP503" in line:
        eap503 += 1
    elif "EAP640" in line:
        eap640 += 1
    elif "EAP853" in line:
        eap853 += 1
    elif "Oscar" in line:
        oscar += 1
    elif "st_august" in line:
        staug += 1
    elif "ESSS CUBA" in line:
        c_c += 1
brazil = angela + courtney + eakin + eap853
colombia = eap255 + eap503 + eap640
cuba = c_c + d_l + oscar
print("Angela: " + str(angela))
print("EAP255: " + str(eap255))
print("Courtney: " + str(courtney))
print("Cuba_Colombia: " + str(c_c))
print("David L: " + str(d_l))
print("Eakin: " + str(eakin))
print("EAP503: " + str(eap503))
print("EAP640: " + str(eap640))
print("EAP853: " + str(eap853))
print("Oscar: " + str(oscar))
print("Spanish Florida: " + str(staug))
print("Brazil: " + str(brazil))
print("Colombia: " + str(colombia))
print("Cuba: " + str(cuba))
# Out:
# Angela: 46257
# EAP255: 126384
# Courtney: 171578
# Cuba_Colombia: 79520
# David L: 1595
# Eakin: 79
# EAP503: 41293
# EAP640: 58228
# EAP853: 9
# Oscar: 28683
# Spanish Florida: 19507
# Brazil: 217923
# Colombia: 225905
# Cuba: 109798

# %%
test = open("DC Test.txt","r")
volumes = 0
for line in test:
    if "Registro" in line:
        volumes += 1
print(volumes)
# Out:
# 9

# %%
newt = open("Test"+"Test","w")
newt.close()

# %%
master = open("DC Test.txt","r")
maco = 1
for line in master:
    if "Registro" in line:
        index = 0
        nc = line.find(",")
        md = open("Maco " + str(maco)+".xml","w")
        title = line[index:nc]
        index = nc + 1
        nc = line.find(",",index)
        typ = line[index:nc]
        index = nc + 1
        nc = line.find(",", index)
        city = line[index:nc]
        index = nc + 1
        nc = line.find(",", index)
        subj = line[index:nc]
        index = nc + 1
        nc = line.find(",", index)
        if index != nc:
            subj = subj + "," + line[index:nc]
        index = nc + 1
        nc = line.find(",", index)
        if index != nc:
            title = line[index:nc]
        if "ç" in title:
            title = "Maco " + str(maco)
        index = nc + 1
        nc = line.find(",", index)
        date = line[index:nc]
        index = nc + 1
        nc = line.find(",", index)
        ext = line[index:nc]
        index = nc + 1
        nc = line.find(",", index)
        lang = "por"
        index = nc + 1
        nc = line.find(",", index)
        cre = line[index + 8:nc]
        index = nc + 1
        nc = line.find(",", index)
        form = line[index:nc]
        index = nc + 1
        nc = line.find(",", index)
        index = nc + 1
        nc = line.find(",", index)
        abst = line[index+1:len(line)-4]
        if (maco == 5 or maco == 7):
            period = "Early Modern"
        else:
            period = "Modern"
        if maco == 1:
            ident = 2223
        elif maco ==2:
            ident = 39001
        elif maco ==3:
            ident = 39003
        elif maco ==4:
            ident = 39005
        elif maco ==5:
            ident = 39008
        elif maco ==6:
            ident = 39013
        elif maco ==7:
            ident = 39016
        elif maco ==8:
            ident = 39019
        elif maco ==9:
            ident = 39021
        
        md.write("<oai_dc:dc xmlns:dc=\"http://purl.org/dc/elements/1.1/\" xmlns:oai_dc=\"http://www.openarchives.org/OAI/2.0/oai_dc/\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xsi:schemaLocation=\"http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd\">")
        md.write("<dc:title>" + title + "</dc:title>")
        md.write("<dc:subject>" + subj + "</dc:subject>")
        md.write("<dc:subject>" + subj + "--Brazil--" + period + "</dc:subject>")
        md.write("<dc:subject>981</dc:subject>")
        md.write("<dc:creator>" + cre + "</dc:creator>")
        md.write("<dc:description>" + abst + "</dc:description>")        
        md.write("<dc:publisher>Slave Societies Digital Archive</dc:publisher>")
        md.write("<dc:contributor>Marshall Eakin(project director)</dc:contributor>")
        md.write("<dc:contributor>Courtney J. Campbell(co-director)</dc:contributor>")
        md.write("<dc:contributor>Solange Pereira da Rocha(co-director)</dc:contributor>")
        md.write("<dc:contributor>Daniel Genkins(metadata creation)</dc:contributor>")
        md.write("<dc:date>"+date+"</dc:date>")
        md.write("<dc:type>Text</dc:type>")
        md.write("<dc:type>" + typ + "</dc:type>")
        md.write("<dc:format>" + form + "</dc:format>")
        md.write("<dc:format>" + ext + "</dc:format>")
        md.write("<dc:identifier>essss:" + str(ident) + "</dc:identifier>")
        md.write("<dc:language>" + lang + "</dc:language>")
        md.write("<dc:coverage>Brazil</dc:coverage>")
        md.write("<dc:coverage>South America--Brazil--Minas Gerais--" + city + "</dc:coverage>")
        md.write("<dc:coverage>-19.98583,-43.84694</dc:coverage>")
        md.write("<dc:coverage>" + period + "</dc:coverage>")
        md.write("<dc:rights>Vanderbilt University makes these historical records available for the limited purposes of individual private study, scholarship, research, teaching, and other educational or instructional uses. No rights of any kind are granted to users with respect to photographs or graphic images published on this site.</dc:rights>")
        md.write("</oai_dc:dc>")
        maco += 1
        md.close()

# %%
quib = open("BL EAP 255 List.csv","r")
for line in quib:    
    index = 0 
    nc = line.find(",",index)
    index = nc + 1 #EAP Project number
    nc = line.find(",",index)
    index = nc + 1 #Reference
    nc = line.find(",",index)
    index = nc + 1 #Location of original material, institution
    nc = line.find(",",index)
    institution = line[index + 1:line.find(",",index)]
    index = nc + 1 #Location of original material, department
    nc = line.find(",",index)
    city = "Quibdó"
    department = line[index + 1:line.find(",",index)]
    index = nc + 1 #Loaction of original material, country
    nc = line.find(",",index)
    country = line[index + 1:line.find("\"",index)]
    index = nc + 1 #Title
    nc = line.find(",",index)
    while line[nc - 1] != "\"":
        nc = line.find(",", nc + 1)
    title = line[index + 1:line.find("\"",index)]
    index = nc + 1 #Description
    nc = line.find(",",index)
    while line[nc - 1] != "\"":
        nc = line.find(",", nc + 1)
    abstract = line[index + 1:line.find("\"",index)]
    index = nc + 1 #Custodial history
    nc = line.find(",",index)
    index = nc + 1 #System of arrangement
    nc = line.find(",",index)
    form = line[index:nc]
    index = nc + 1 #Administrative context
    nc = line.find(",",index)
    index = nc + 1 #Dates of original material
    nc = line.find(",",index)
    if ("1936 tomo 5" or "1936 tomo 2" or "1936 tomo 1" or "1931 tomo 1" or "1929 tomo 4" or "1929 tomo 1" or "Certificados (1926)" or "(1927, 1943)" or "Escritura (1922)" or "(1902)" or "(1897)" or "(1870-1871)" or "(1853)" or "1834" or "1827") in title:
        date = line[index:nc]
    else:
        sday = line[index:index + 2]
        index = index + 3
        smon = line[index:index + 3]
        index = index + 4
        syear = line[index:index + 4]
        index = index + 7
        eday = line[index:index + 2]
        index = index + 3
        emon = line[index:index + 3]
        index = index + 4
        eyear = line[index:index + 4]
        if smon == "Jan":
            smon = "01"
        elif smon == "Feb":
            smon = "02"
        elif smon == "Mar":
            smon = "03"
        elif smon == "Apr":
            smon = "04"
        elif smon == "May":
            smon = "05"
        elif smon == "Jun":
            smon = "06"
        elif smon == "Jul":
            smon = "07"
        elif smon == "Aug":
            smon = "08"
        elif smon == "Sep":
            smon = "09"
        elif smon == "Oct":
            smon = "10"
        elif smon == "Nov":
            smon = "11"
        else:
            smon = "12"
        if emon == "Jan":
            emon = "01"
        elif emon == "Feb":
            emon = "02"
        elif emon == "Mar":
            emon = "03"
        elif emon == "Apr":
            emon = "04"
        elif emon == "May":
            emon = "05"
        elif emon == "Jun":
            emon = "06"
        elif emon == "Jul":
            emon = "07"
        elif emon == "Aug":
            emon = "08"
        elif emon == "Sep":
            emon = "09"
        elif emon == "Oct":
            emon = "10"
        elif emon == "Nov":
            emon = "11"
        else:
            emon = "12"
        date = syear + "-" + smon + "-" + sday + "/" + eyear + "-" + emon + "-" + eday
    index = nc + 1 #Era
    nc = line.find(",",index)
    index = nc + 1 #Calendar
    nc = line.find(",",index)
    index = nc + 1 #Volume and issue number
    nc = line.find(",",index)
    index = nc + 1 #Extent and format
    nc = line.find(",",index)
    extent = line[index:nc]
    index = nc + 1 #Physical characteristics
    nc = line.find(",",index)        
    while line[nc + 1] != "S":
        nc = line.find(",", nc + 1)
    note = line[index:nc]  
    index = nc + 1 #Languages of material
    nc = line.find(",",index)
    language = "spa"
        
    print("title: " + title)
    print("institution: " + institution)
    print("department: " + department)
    print("country: " + country)
    print("abstract: " + abstract)
    print("form: " + form)
    print("date: " + date)
    print("extent: " + extent)
    print("note: " + note + "\n")

# %%
if ("trep" or "gun") in "fishtree":
    print("yes")
else:
    print("no")
# Out:
# no

# %%
print(2+2)
# Out:
# 4

# %%
quib = open("BL EAP 255 List.csv","r")
lines = 0
for line in quib:
    lines += 1
print(lines)
quib.close()
# Out:
# 136

# %%
quib = open("BL EAP 255 List.csv","r")
for line in quib:    
    index = 0 
    nc = line.find(",",index)
    index = nc + 1 #EAP Project number
    nc = line.find(",",index)
    index = nc + 1 #Reference
    nc = line.find(",",index)
    index = nc + 1 #Location of original material, institution
    nc = line.find(",",index)
    institution = line[index + 1:line.find(",",index)]
    index = nc + 1 #Location of original material, department
    nc = line.find(",",index)
    city = "Quibdó"
    department = line[index + 1:line.find(",",index)]
    index = nc + 1 #Loaction of original material, country
    nc = line.find(",",index)
    country = line[index + 1:line.find("\"",index)]
    index = nc + 1 #Title
    nc = line.find(",",index)
    while line[nc + 1] != "\"":        
        nc = line.find(",", nc + 1)
    if line[nc + 1] == "\"":
        title = line[index:line.find("\"",index) - 1]
    else:        
        title = line[index:line.find("T",index) - 1]
    print(institution)
    print(department)
    print(country)
    print(title)
    print("\n")
quib.close()
# Out:
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Venta de Esclavo
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras (1813)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras y Venta (1814)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras (1815)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras (1818)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras (1819)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras (1827)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras (1828)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Venta de Esclavo (1831)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Notaría Libro (1832)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Documentos Varios (1833)
#
#
# Notaria Primera de Quibdó
# Chocó
# Colombia
# Libro de Escrituras y Demas Instrumentos Públicos (1834)
# ...

# %%
test = open("Maco 1.xml","r")
print(test)
test.close()
# Out:
# <_io.TextIOWrapper name='Maco 1.xml' mode='r' encoding='cp1252'>

# %%
ret = open("DC Test.txt",'r')
print(ret)
ret.close()
# Out:
# <_io.TextIOWrapper name='DC Test.txt' mode='r' encoding='cp1252'>

# %%
with open(r"Test.txt",'r') as infile:
    data = infile.read()
    volumes = 0
    for line in data:
        print(line)
        volumes += 1
    print(str(volumes))
# Out:
# f
# i
# s
# h
# t
# r
# e
# e
# s
#
#
# m
# o
# n
# k
# e
# y
#
#
# g
# r
# a
# p
# h
# 22

# %%
quib = open("Form.csv","r")
lines = 0
for line in quib:
    lines += 1
print(lines)
quib.close()
# Out:
# 3

# %%
test = open("Maco 4.xml","r")
lines = 0
for line in test:
    print(line)
    lines += 1
print(lines)
test.close()
# Out:
# <oai_dc:dc xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:oai_dc="http://www.openarchives.org/OAI/2.0/oai_dc/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd"><dc:title>Maco 4</dc:title><dc:subject>Obitos</dc:subject><dc:subject>Obitos--Brazil--Modern</dc:subject><dc:subject>981</dc:subject><dc:creator>V. Joao de Deus Macario</dc:creator><dc:description>These papers are in very good condition, with some fading around the edges. This packet contains obituary information for the parish of Sabara, MG as it relates to the Morro Velho Company. Names, ages, dates, civil status and burial location are listed.</dc:description><dc:publisher>Slave Societies Digital Archive</dc:publisher><dc:contributor>Marshall Eakin(project director)</dc:contributor><dc:contributor>Courtney J. Campbell(co-director)</dc:contributor><dc:contributor>Solange Pereira da Rocha(co-director)</dc:co
# ...

# %%
#delete thumbs.db
import errno, os, stat, shutil

def handleRemoveReadonly(func, path, exc):
  excvalue = exc[1]
  if func in (os.rmdir, os.remove) and excvalue.errno == errno.EACCES:
      os.chmod(path, stat.S_IRWXU| stat.S_IRWXG| stat.S_IRWXO) # 0777
      func(path)
  else:
      raise

volsDir = input('Enter directory to be cleansed of evil: ')
        
for folderName, subFolders, files in os.walk(volsDir):
    if files:
        for file in files:
            if ('Thumbs.db' in file) or ('DS_Store' in file) or ('bs.db' in file) or ('ZbThumbnail.info' in file):
                os.remove(folderName + '\\' + file)
                print(folderName + '\\' + file + ' deleted!')
# Out:
# Enter directory to be cleansed of evil: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\new_additions
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-2-a5903d217ee4> in <module>()
#      16         for file in files:
#      17             if ('Thumbs.db' in file) or ('DS_Store' in file) or ('bs.db' in file) or ('ZbThumbnail.info' in file):
# ---> 18                 os.remove(folderName + '\\' + file)
#      19                 print(folderName + '\\' + file + ' deleted!')
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\new_additions\\Thumbs.db'

# %%
os.path.isfile('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\EAP255_raw\\Valle_del_Cauca\\EAP255_VALLEDELCAUCA_BUENAVENTURA_NOTARIA_NOTARIAUNICA_01\\Thumbs.db')
# Out:
# True

# %%
#merge volume sections
import os,shutil
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
relPath = 'Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Gonçalo' #directory to merge volume sections in
for folderName, subFolders, files in os.walk(relPath):
    if files and not '.1' in folderName:
        newFolder = folderName[:folderName.find('.')] + '.1'        
        for file in files:            
            if (not os.path.exists(newFolder + '\\' + file)) and os.path.isdir(newFolder):
                shutil.move(folderName + '\\' + file,newFolder)
            elif not os.path.isdir(newFolder):
                print('Attempting to move ' + file + ' but ' + newFolder + ' does not exist.')
            else:
                print('Duplicate image name at ' + newFolder + '\\' + file)
for folderName, subFolders, files in os.walk(relPath):
    if not files and not subFolders:
        os.rmdir(folderName)

# %%
import os,shutil
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
relPath = 'Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Saquarema' 
for folderName, subFolders, files in os.walk(relPath):
    if not files and not subFolders:        
        os.rmdir(folderName)

# %%
#fix volume where sections are arranged in sub-directories (DOES NOT WORK)
import os,shutil
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
volPath = 'Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Santa Isabel\\S. Isabel 007'
relPath = 'Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Santa Isabel\\S. Isabel 007\\007.' #directory to merge volume sections in
numSect = 13
currSect = 1
currPage = 1
while currSect <= numSect:    
    currSectPath = relPath + str(currSect)
    for folderName, subFolders, files in os.walk(currSectPath):
        if files:
            files.sort()
        for file in files:            
            shutil.move(folderName + '\\' + file,volPath + '\\' + 'S. Isabel7' + '_' + str(currPage) + '.JPG')
            currPage += 1
    currSect += 1

# %%
import os,shutil
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
volPath = 'Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Santa Isabel\\S. Isabel 005'
for folderName, subFolders, files in os.walk(volPath):
    for file in files:
        newFileName = file[0:file.find('l') + 1] + '5' + file[file.find('_'):]
        shutil.move(folderName + '\\' + file, folderName + '\\' + newFileName)

# %%
import os,shutil
os.chdir('C:\\Users\\genkindn\\Zip Test')
shutil.make_archive('C:\\Users\\genkindn\\Zip Target\\myCoolArchive', 'zip')
# Out:
# 'C:\\Users\\genkindn\\Zip Target\\myCoolArchive.zip'

# %%
test = input()
print(test)
# Out:
# Hello world!
# Hello world!

# %%
from PIL import Image

file_name = input('Enter file name: ')
if file_name.find('.') >= 0:
    name, extension = file_name.split('.')
    if extension in ['jpg','JPG']:
        print('Valid extension.')
    else:
        print('Invalid extension.')
else:
    print('Invalid file name.')
# Out:
# Enter file name: hiu
# Invalid file name.

# %%
##### all-in-one image rotator (be careful, images will be rotated immediately)

import os 
docName = input('Enter a name for the instruction file: ') 
os.chdir('C:\\Users\\genkindn\\Rotation Lists') 
writeDoc = open(docName + '.txt','w') 
needVol = True 
endWrite = False 
while not endWrite: 
    if needVol: 
        nextInst = input('Enter volume directory or \'end\' to finish: ') 
        if 'end' in nextInst: 
            writeDoc.close() 
            endWrite = True 
        elif os.path.isdir(nextInst): 
            writeDoc.write(nextInst + '\n') 
            activeVol = nextInst 
            needVol = False 
            needExt = True 
        else: 
            print('Invalid input.') 
    elif needExt: 
        nextInst = input('Enter file extensions (case sensitive): ') 
        if ('jpg' in nextInst) or ('JPG' in nextInst) or ('tif' in nextInst): 
            ext = nextInst 
            needExt = False 
            needCase = True 
        else: 
            print('Invalid input.') 
    elif needCase: 
        nextInst = input('Enter the rotation case (r, l, or f) or \'done\' to change volumes: ') 
        if 'done' in nextInst: 
            needCase = False 
            needVol = True 
        elif (nextInst == 'r') or (nextInst == 'l') or (nextInst == 'f'): 
            writeDoc.write(nextInst + ':') 
            needCase = False 
            needStart = True 
        else: 
            print('Invalid input.') 
    elif needStart: 
        nextInst = input('Enter the number of the first image: ')
        if os.path.isfile(activeVol + '\\' + nextInst + '.' + ext): 
            writeDoc.write(nextInst + '.' + ext + '-') 
            start = nextInst 
            needStart = False 
            needFinish = True 
        else: 
            print('Invalid input.')
    elif needFinish: 
        nextInst = input('Enter the number of the last image or either the next rotation or \'null\' if only one: ') 
        if os.path.isfile(activeVol + '\\' + nextInst + '.' + ext): 
            writeDoc.write(nextInst + '.' + ext + '\n') 
            needFinish = False 
            needCase = True 
        elif 'null' in nextInst: 
            writeDoc.write(start + '.' + ext + '\n') 
            needFinish = False 
            needCase = True 
        elif (nextInst == 'r') or (nextInst == 'l') or (nextInst == 'f'): 
            writeDoc.write(start + '.' + ext + '\n') 
            needFinish = False 
            writeDoc.write(nextInst + ':') 
            needStart = True 
        else: 
            print('Invalid input: ' + activeVol + '\\' + nextInst + '.' + ext.upper()) 
    else: 
            print('You broke it.') 

from PIL import Image 
rotText = open(docName + '.txt','r') 
for line in rotText: 
    if line.find('\\') != -1: 
        actDir = line[:len(line) - 1] 
        os.chdir(actDir) 
        print("Now working on " + actDir) 
    elif (line.find('-') != -1) and (line.find('\\') == -1): 
        firPer = line.find('.') 
        stIm = line[line.find(':') + 1:firPer] 
        finIm = line[line.find('-') + 1:line.find('.',firPer + 1)] 
        ext = line[firPer:line.find('-')] 
        rotCase = line[0:1] 
        currIm = int(stIm) 
        imRot = 0 
        while currIm <= int(finIm):
            imDir = actDir + '\\' + str(currIm) + ext 
            imExists = os.path.isfile(imDir) 
            if imExists: 
                  rotIm = Image.open(imDir) 
            if (rotCase == 'r') and imExists: 
                width = rotIm.size[0] 
                height = rotIm.size[1] 
                if width > height: 
                    rotIm = rotIm.resize((width,width)) 
                elif height > width: 
                    rotIm = rotIm.resize((height,height)) 
                rotIm = rotIm.rotate(270) 
                rotIm = rotIm.resize((height,width)) 
                rotIm.save(imDir)
                #print('Rotate right ' + imDir)
                rotIm.close()
                imRot += 1
            elif (rotCase =='f') and imExists:                    
                rotIm = rotIm.rotate(180)
                rotIm.save(imDir)
                #print('Flip ' + imDir)
                rotIm.close()                
                imRot += 1
            elif (rotCase == 'l') and imExists:
                width = rotIm.size[0]
                height = rotIm.size[1]
                if width > height:
                    rotIm = rotIm.resize((width,width))
                elif height > width:
                    rotIm = rotIm.resize((height,height))
                rotIm = rotIm.rotate(90)
                rotIm = rotIm.resize((height,width))
                rotIm.save(imDir)
                #print('Rotate left ' + imDir)
                rotIm.close()
                imRot += 1
            elif imExists:
                print('Invalid rotCase at: ' + stIm)
                rotIm.close()
            currIm += 1
        if rotCase == 'r':
            print('Images ' + stIm + ' through ' + finIm + ' rotated right.')
        elif rotCase == 'f':
            print('Images ' + stIm + ' through ' + finIm + ' flipped.')
        elif rotCase == 'l':
            print('Images ' + stIm + ' through ' + finIm + ' rotated left.')
        print(str(imRot) + ' total images rotated.')
rotText.close() 
print('Rotation completed.')
# Out:
# Enter a name for the instruction file: Oscar_IMH_B9302
# Enter volume directory or 'end' to finish: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\Oscar\Iglesia de Mayari. Holguin\Libro 12 de bautizo de blancos y de color 1893-1902
# Enter file extensions (case sensitive): JPG
# Enter the rotation case (r, l, or f) or 'done' to change volumes: r
# Enter the number of the first image: 1958
# Enter the number of the last image or either the next rotation or 'null' if only one: r
# Enter the number of the first image: 2131
# Enter the number of the last image or either the next rotation or 'null' if only one: null
# Enter the rotation case (r, l, or f) or 'done' to change volumes: done
# Enter volume directory or 'end' to finish: end
# Now working on \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\Oscar\Iglesia de Mayari. Holguin\Libro 12 de bautizo de blancos y de color 1893-1902
# Images 1958 through 1958 rotated right.
# ...

# %%
#delete thumbs.db and check whether the number of images matches numbering

import errno, os, stat, shutil

def handleRemoveReadonly(func, path, exc):
  excvalue = exc[1]
  if func in (os.rmdir, os.remove) and excvalue.errno == errno.EACCES:
      os.chmod(path, stat.S_IRWXU| stat.S_IRWXG| stat.S_IRWXO) # 0777
      func(path)
  else:
      raise

directory = input('Enter a directory to be checked for consistency: ')

#for folder, sub_folders, files in os.walk(directory):
    #if files:
        #for file in files:
            #if ('Thumbs.db' in file) or ('DS_Store' in file) or ('bs.db' in file) or ('ZbThumbnail.info' in file):
                #os.remove(folder + '\\' + file)
                #print(folder + '\\' + file + ' deleted!')
                
for folder, sub_folders, files in os.walk(directory):
    if files:                
        files.sort()
        final_file_name, extension = files[len(files) - 1].split('.')
        final_file_number = int(final_file_name[final_file_name.find("_") + 1:])
        if final_file_number != len(files):
            print("Problem with " + folder)
        #else:
            #print(folder + "is good")
# Out:
# Enter a directory to be checked for consistency: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\EAP503_ingest
# Problem with \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\EAP503_ingest\PROYECTO EAP503\EAP503_NOTARIA_PRIMERA_DE_RIOHACHA_009

# %%
g = [1, 2]
len(g)
# Out:
# 2

# %%
#exif stripper (copy of cell from Image Rotation)
import os
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

image_directory = input('Enter directory of images: ')

for folder,sub_directory,files in os.walk(image_directory):
    print('Now working in ' + folder)
    for file in files:
        image_location = folder + '\\' + file       
        name, extension = file.split('.')
        if extension in ['jpg','JPG']:
            im = Image.open(image_location)#.load()
            #print(im.format, im.size, im.mode)
            stripped = im.rotate(0)
            stripped.save(image_location)
            im.close()
            stripped.close()
        else:
            if ('Thumbs.db' in file) or ('DS_Store' in file) or ('bs.db' in file):
                os.unlink(folder + '\\' + file)
                print(folder + '\\' + file + ' deleted!')
print('Stripping completed!')
# Out:
# Enter directory of images: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\David_LaFevor\ESSS data\Espiritu Santo, Libro de Baptismos de Indios, Negros y Mulatos, 1737-1748
# Now working in \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\David_LaFevor\ESSS data\Espiritu Santo, Libro de Baptismos de Indios, Negros y Mulatos, 1737-1748
# Stripping completed!
