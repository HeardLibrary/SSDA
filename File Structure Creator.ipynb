# %%
import shutil, os

# %%
os.chdir('C:\\')

# %%
os.chdir('C:\\Users\\genkindn')

# %%
shutil.copy('C:\\Users\\genkindn\\spam.txt', 'C:\\Users\\genkindn\\deli')
# Out:
# 'C:\\Users\\genkindn\\deli\\spam.txt'

# %%
shutil.copy('spam.txt','spamz.txt')
# Out:
# 'spamz.txt'

# %%
shutil.copytree('deli', 'deliz')
# Out:
# 'deliz'

# %%
#create individual subdirectories for pages 
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
volumes = 0
pages = 0
volPages = 0
#for folderName, subFolders, fileNames in os.walk('Courtney\\EAP255\\Chocó\\Quibdó\\Notarias\\Notaria_Primera_de_Quidbó'):
for folderName, subFolders, fileNames in os.walk('Courtney\\EAP255\\Chocó\\Quibdó\\Notarias\\Notaria_Primera_de_Quidbó'):
    volumes += 1    
    volPages = 0
    print("Now working on " + folderName)
    page = 1
    fileNames.sort()
    for fileName in fileNames:            
            if 'tif' in fileName:
                if not os.path.exists('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page)):
                    os.makedirs('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page))            
                if os.path.exists(folderName + '\\' + fileName):                    
                    shutil.move(folderName + '\\' + fileName,folderName + '\\' + str(page) + '\\OBJ.tif')
                    page += 1
                    pages += 1
                    volPages += 1
            else:                
                os.unlink(folderName + '\\' + fileName)
                print(folderName + '\\' + fileName + ' deleted!') 
    print(str(volPages) + " moved.")
print("Total volumes: " + str(volumes - 1))
print("Total pages: " + str(pages))
# Out:
# Now working on Courtney\EAP255\Chocó\Quibdó\Notarias\Notaria_Primera_de_Quidbó
# 0 moved.
# Now working on Courtney\EAP255\Chocó\Quibdó\Notarias\Notaria_Primera_de_Quidbó\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_005
# Courtney\EAP255\Chocó\Quibdó\Notarias\Notaria_Primera_de_Quidbó\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_005\Thumbs.db deleted!
# 271 moved.
# Now working on Courtney\EAP255\Chocó\Quibdó\Notarias\Notaria_Primera_de_Quidbó\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_125
# Courtney\EAP255\Chocó\Quibdó\Notarias\Notaria_Primera_de_Quidbó\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_125\Thumbs.db deleted!
# 357 moved.
# Now working on Courtney\EAP255\Chocó\Quibdó\Notarias\Notaria_Primera_de_Quidbó\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_032
# 277 moved.
# Now working on Courtney\EAP255\Chocó\Quibdó\Notarias\Notaria_Primera_de_Quidbó\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_139
# 630 moved.
# ...

# %%
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
for folderName, subfolders, filenames in os.walk('Fish'):
    print('The current folder is ' + folderName)

    for subfolder in subfolders:
        print('SUBFOLDER OF ' + folderName + ': ' + subfolder)
    for filename in filenames:
        print('FILE INSIDE ' + folderName + ': '+ filename)

    print('')
# Out:
# The current folder is Fish
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_005
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_125
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_032
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_139
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_012
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_112
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_050
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_091
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_025
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_014
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_129
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_093
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_079
# SUBFOLDER OF Fish: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003
# ...

# %%
#copy metadata records to batch directory
os.chdir('C:\\Users\\genkindn')
MODScopied = 0
DCcopied = 0
for folderName, subFolders, fileNames in os.walk('255 Batch'):
    for fileName in fileNames:
        if 'Quibdo' in fileName:
            print('Now working on: ' + fileName)
            usco = fileName.find('_')
            if fileName.find('_',usco + 1) > -1:
                number = fileName[usco + 1:fileName.find('_',usco + 1)]
            else:
                number = fileName[usco + 1:fileName.find('.')]
            num = int(number)
            if num < 10:
                number = "00" + str(num)
            elif num < 100:
                number = "0" + str(num)
            #print('Batch Build Test\\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_' + number + '\\DC.xml')
            volLoc = '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Courtney\\EAP255\\Chocó\\Quibdó\\Notarias\\Notaria_Primera_de_Quidbó\\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_'
            if ('MODS' in fileName) and (os.path.exists(volLoc + number)):
                shutil.copy(folderName + '\\' + fileName,volLoc + number + '\\MODS.xml')
                print('MODS copied to ' + number)
                MODScopied += 1
            elif os.path.exists(volLoc + number):
                shutil.copy(folderName + '\\' + fileName,volLoc + number + '\\DC.xml')
                print('DC copied to ' + number)
                DCcopied += 1
print('MODS records copied: ' + str(MODScopied))
print('DC records copied: ' + str(DCcopied))
# Out:
# Now working on: Quibdo_1.xml
# DC copied to 001
# Now working on: Quibdo_10.xml
# DC copied to 010
# Now working on: Quibdo_100.xml
# DC copied to 100
# Now working on: Quibdo_100_MODS.xml
# MODS copied to 100
# Now working on: Quibdo_101.xml
# DC copied to 101
# Now working on: Quibdo_101_MODS.xml
# MODS copied to 101
# Now working on: Quibdo_102.xml
# DC copied to 102
# Now working on: Quibdo_102_MODS.xml
# MODS copied to 102
# Now working on: Quibdo_103.xml
# DC copied to 103
# Now working on: Quibdo_103_MODS.xml
# MODS copied to 103
# Now working on: Quibdo_104.xml
# DC copied to 104
# Now working on: Quibdo_104_MODS.xml
# MODS copied to 104
# Now working on: Quibdo_105.xml
# DC copied to 105
# Now working on: Quibdo_105_MODS.xml
# MODS copied to 105
# Now working on: Quibdo_106.xml
# DC copied to 106
# Now working on: Quibdo_106_MODS.xml
# MODS copied to 106
# Now working on: Quibdo_107.xml
# DC copied to 107
# Now working on: Quibdo_107_MODS.xml
# MODS copied to 107
# ...

# %%
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')

# %%
shutil.copy('tobeprocessed.txt','copytest.txt')
# Out:
# 'copytest.txt'

# %%
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Courtney\\EAP255\\Chocó\\Quibdó\\Notarias')

# %%
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Batch Test')

# %%
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')

# %%
for folderName, subfolders, filenames in os.walk('Batch Test'):
    print('The current folder is ' + folderName)

    for subfolder in subfolders:
        print('SUBFOLDER OF ' + folderName + ': ' + subfolder)
    for filename in filenames:
        print('FILE INSIDE ' + folderName + ': '+ filename)

    print('')
# Out:
# The current folder is Batch Test
# SUBFOLDER OF Batch Test: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003
# SUBFOLDER OF Batch Test: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_001
# SUBFOLDER OF Batch Test: EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_002
#
# The current folder is Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003
# FILE INSIDE Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003: IMG_0261.tif
# FILE INSIDE Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003: IMG_0322.tif
# FILE INSIDE Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003: IMG_0286.tif
# FILE INSIDE Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003: IMG_0126.tif
# FILE INSIDE Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003: IMG_0167.tif
# FILE INSIDE Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003: IMG_0324.tif
# FILE INSIDE Batch Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_003: IMG_0072.tif
# ...

# %%
#code for sort
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
for folderName, subfolders, fileNames in os.walk('Sort Test'):
    fileNames.sort()
    for file in fileNames:
        print(folderName + '\\' + file)
    print('Next book.')
# Out:
# Next book.
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0001.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0002.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0003.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0004.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0005.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0006.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0007.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0008.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0009.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0010.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0011.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0012.tif
# Sort Test\EAP255_CHOCO_QUIBDO_NOTARIAS_NOTARIAPRIMERA_013\IMG_0013.tif
# ...

# %%
strNum = '1534'
intNum = int(strNum)
print(str(intNum))
# Out:
# 1534

# %%
os.chdir('C:\\Users\\genkindn')
for folderName, subfolders, fileNames in os.walk('255 Batch'):
    fileNames.sort()
    for file in fileNames:
        print(folderName + '\\' + file)
# Out:
# 255 Batch\BL Metadata Generation.ipynb
# 255 Batch\Master.xml
# 255 Batch\Quibdo_1.xml
# 255 Batch\Quibdo_10.xml
# 255 Batch\Quibdo_100.xml
# 255 Batch\Quibdo_100_MODS.xml
# 255 Batch\Quibdo_101.xml
# 255 Batch\Quibdo_101_MODS.xml
# 255 Batch\Quibdo_102.xml
# 255 Batch\Quibdo_102_MODS.xml
# 255 Batch\Quibdo_103.xml
# 255 Batch\Quibdo_103_MODS.xml
# 255 Batch\Quibdo_104.xml
# 255 Batch\Quibdo_104_MODS.xml
# 255 Batch\Quibdo_105.xml
# 255 Batch\Quibdo_105_MODS.xml
# 255 Batch\Quibdo_106.xml
# 255 Batch\Quibdo_106_MODS.xml
# 255 Batch\Quibdo_107.xml
# 255 Batch\Quibdo_107_MODS.xml
# 255 Batch\Quibdo_108.xml
# 255 Batch\Quibdo_108_MODS.xml
# 255 Batch\Quibdo_109.xml
# 255 Batch\Quibdo_109_MODS.xml
# 255 Batch\Quibdo_10_MODS.xml
# 255 Batch\Quibdo_11.xml
# 255 Batch\Quibdo_110.xml
# 255 Batch\Quibdo_110_MODS.xml
# 255 Batch\Quibdo_111.xml
# 255 Batch\Quibdo_111_MODS.xml
# 255 Batch\Quibdo_112.xml
# 255 Batch\Quibdo_112_MODS.xml
# 255 Batch\Quibdo_113.xml
# 255 Batch\Quibdo_113_MODS.xml
# ...

# %%
#create individual subdirectories for pages (update freq before executing)
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
volumes = 0
pages = 0
volPages = 0
freq = 'Maricá'
for folderName, subFolders, fileNames in os.walk('Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq):
    volumes += 1    
    volPages = 0
    print("Now working on " + folderName)
    page = 1
    fileNames.sort()
    for fileName in fileNames:            
            if ('tif' in fileName) or ('JPG' in fileName) or ('jpg' in fileName):
                ext = fileName [fileName.find('.'):]
                if not os.path.exists('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page)):
                    os.makedirs('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page))            
                if os.path.exists(folderName + '\\' + fileName):                    
                    shutil.move(folderName + '\\' + fileName,folderName + '\\' + str(page) + '\\OBJ' + ext)
                    page += 1
                    pages += 1
                    volPages += 1
            else:                
                os.unlink(folderName + '\\' + fileName)
                print(folderName + '\\' + fileName + ' deleted!') 
    print(str(volPages) + " moved.")
print("Total volumes: " + str(volumes - 1))
print("Total pages: " + str(pages))
# Out:
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Maricá
# 0 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 011.1
# Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 011.1\MODS.xml deleted!
# 19 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 016.1
# Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 016.1\MODS.xml deleted!
# 68 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 003.1
# Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 003.1\MODS.xml deleted!
# 67 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 005.1
# Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 005.1\MODS.xml deleted!
# 5 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 013.1
# Angela\ESSS\digitalizacao Niteroi\Livros\Maricá\Maricá 013.1\MODS.xml deleted!
# 3 moved.
# ...

# %%
#copy metadata records to batch directory
import os, shutil
os.chdir('C:\\Users\\genkindn')
MODScopied = 0
DCcopied = 0
for folderName, subFolders, fileNames in os.walk('627 Batch'):
    for fileName in fileNames:
        if 'AHP' in fileName:
            print('Now working on: ' + fileName)
            number = '0001'
            volLoc = '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Permissions Test\\EAP627_ArquivoHistoricodaParaiba_' 
            if ('MODS' in fileName) and (os.path.exists(volLoc + number)):
                shutil.copy(folderName + '\\' + fileName,volLoc + number + '\\MODS.xml')
                print('MODS copied to ' + number)
                MODScopied += 1
            elif os.path.exists(volLoc + number):
                shutil.copy(folderName + '\\' + fileName,volLoc + number + '\\DC.xml')
                print('DC copied to ' + number)
                DCcopied += 1
print('MODS records copied: ' + str(MODScopied))
print('DC records copied: ' + str(DCcopied))
# Out:
# Now working on: AHP0001DC.txt
# DC copied to 0001
# Now working on: AHP0001MODS.txt
# MODS copied to 0001
# MODS records copied: 1
# DC records copied: 1

# %%
print('Reserved.')
# Out:
# Reserved.

# %%
#create zip archive
import os, shutil
freq = 'Saquarema 2'
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq)
zipName = freq + ' Batch'
shutil.make_archive(zipName, 'zip')
# Out:
# 'Saquarema 2 Batch.zip'

# %%
#all-in-one batch converter (update freq and volume start/finish before executing)
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
volumes = 0
pages = 0
volPages = 0
freq = 'Saquarema'
for folderName, subFolders, fileNames in os.walk('Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq):
    volumes += 1    
    volPages = 0
    print("Now working on " + folderName)
    page = 1
    fileNames.sort()
    for fileName in fileNames:            
            if ('tif' in fileName) or ('JPG' in fileName) or ('jpg' in fileName):
                ext = fileName [fileName.find('.'):]
                if not os.path.exists('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page)):
                    os.makedirs('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page))            
                if os.path.exists(folderName + '\\' + fileName):                    
                    shutil.move(folderName + '\\' + fileName,folderName + '\\' + str(page) + '\\OBJ' + ext)
                    page += 1
                    pages += 1
                    volPages += 1
            else:                
                os.unlink(folderName + '\\' + fileName)
                print(folderName + '\\' + fileName + ' deleted!') 
    print(str(volPages) + " moved.")
print("Total volumes: " + str(volumes - 1))
print("Total pages: " + str(pages))
relDir = '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq + '\\'
activeVol = 1
volsWritten = 0
finVol = 19
while activeVol <= finVol:
    if activeVol <= 9:
        absDir = freq + ' 00' + str(activeVol) + '.1'
    else:
        absDir = freq + ' 0' + str(activeVol) + '.1'
    volDir = relDir + absDir
    os.chdir(volDir)
    minMODS = open("MODS.xml","w",encoding='utf-8')
    minMODS.write("<mods xmlns=\"http://www.loc.gov/mods/v3\" xmlns:mods=\"http://www.loc.gov/mods/v3\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">")
    minMODS.write("<titleInfo>")
    minMODS.write("<title>" + absDir + "</title>")
    minMODS.write("</titleInfo>")
    minMODS.write("</mods>")
    minMODS.close()
    activeVol += 1
    volsWritten += 1
print('Basic metadata written for ' + str(volsWritten) + ' volumes.')
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq)
zipName = freq + ' Batch'
shutil.make_archive(zipName, 'zip')
# Out:
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema
# 0 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 009.1
# 21 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 002.1
# 361 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 004.1
# 18 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 015.1
# 139 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 006.1
# 165 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 008.1
# Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 008.1\Thumbs.db deleted!
# 202 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 017.1
# 313 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Saquarema\Saquarema 003.1
# 924 moved.
# ...

# %%
print('Reserved for future errors. Also, why is there a row number???')
# Out:
# Reserved for future errors. Also, why is there a row number???

# %%
#renumber individual page directories so that they're sortable (update freq before running)
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
volumes = 0
pages = 0
volPages = 0
freq = 'Maricá'
for folderName, subFolders, fileNames in os.walk('Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq):
    if subFolders and fileNames and (folderName.find('.1') != -1):
        for subFolder in subFolders:
            folderNum = int(subFolder)
            if folderNum < 10:
                os.rename(folderName + '\\' + subFolder, folderName + '\\00' + subFolder)
            elif folderNum < 100:    
                os.rename(folderName + '\\' + subFolder, folderName + '\\0' + subFolder)
            elif folderNum < 1000:
                os.rename(folderName + '\\' + subFolder, folderName + '\\' + subFolder)
            else:
                print('It is over 1000!')

# %%
#THIS CODE DOES NOT WORK UNLESS SUBFOLDERS ARE PADDED
#pop images out of sortable sub-folders (update freq before running)
import shutil, os
volsDir = input('Enter absolute directory of volume: ')
os.chdir(volsDir)

for folderName, subFolders, fileNames in os.walk(volsDir):
    if subFolders and fileNames and (folderName.find('.1') != -1):
        print('Now working on ' + folderName)
        subFolders.sort()
        page = 1
        for subFolder in subFolders:            
            for x, y, foldIms in os.walk(folderName + '\\' + subFolder):
                for foldIm in foldIms:
                    ext = foldIm[foldIm.find('.'):]
                    if page < 10:
                        paddedPage = '00' + str(page)
                    elif page < 100:
                        paddedPage = '0' + str(page)
                    else:
                        paddedPage = str(page)                    
                    shutil.move(folderName + '\\' + subFolder + '\\' + foldIm, folderName + '\\' + paddedPage + ext)
                    page += 1
# Out:
# Enter absolute directory of volume: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\Angela\ESSS\digitalizacao Niteroi\Livros\Jacutinga\Jacutinga 003.1
# Now working on \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\Angela\ESSS\digitalizacao Niteroi\Livros\Jacutinga\Jacutinga 003.1

# %%
#delete empty sub-folders
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
freq = 'Jacutinga'
toDelete = []
for folderName, subFolders, fileNames in os.walk('Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq):
    if (not subFolders) and (not fileNames):
        toDelete.append(folderName)
for emptyFolder in toDelete:
    os.unlink(emptyFolder)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-35-4319a1f65e42> in <module>()
#       8         toDelete.append(folderName)
#       9 for emptyFolder in toDelete:
# ---> 10     os.unlink(emptyFolder)
#
# PermissionError: [WinError 5] Access is denied: 'Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Jacutinga\\Jacutinga 006.1\\156'

# %%
#don't even ask 
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
volumes = 0
pages = 0
volPages = 0
freq = 'Murica'
for folderName, subFolders, fileNames in os.walk('Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq):
    volumes += 1    
    volPages = 0
    print("Now working on " + folderName)
    page = 305
    fileNames.sort()
    for fileName in fileNames:            
            if ('tif' in fileName) or ('JPG' in fileName) or ('jpg' in fileName):
                ext = fileName [fileName.find('.'):]
                if not os.path.exists('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page)):
                    os.makedirs('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\' + folderName + '\\' + str(page))            
                if os.path.exists(folderName + '\\' + fileName):                    
                    shutil.move(folderName + '\\' + fileName,folderName + '\\' + str(page) + '\\OBJ' + ext)
                    page += 1
                    pages += 1
                    volPages += 1
            else:                
                os.unlink(folderName + '\\' + fileName)
                print(folderName + '\\' + fileName + ' deleted!') 
    print(str(volPages) + " moved.")
print("Total volumes: " + str(volumes - 1))
print("Total pages: " + str(pages))
# Out:
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Murica
# 0 moved.
# Now working on Angela\ESSS\digitalizacao Niteroi\Livros\Murica\Murica 001.1
# 236 moved.
# Total volumes: 1
# Total pages: 236

# %%
#make image file names sortable (edit freq before running)
import shutil, os
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')
freq = 'Santa Isabel\\S. Isabel 007.1'
for folderName, subFolders, fileNames in os.walk('Angela\\ESSS\\digitalizacao Niteroi\\Livros\\' + freq):
    if fileNames:
        for fileName in fileNames:
            fileNum = int(fileName[:fileName.find('.')])
            if fileNum < 10:
                os.rename(folderName + '\\' + fileName, folderName + '\\00' + fileName)
            elif folderNum < 100:    
                os.rename(folderName + '\\' + fileName, folderName + '\\0' + fileName)
            elif folderNum < 1000:
                os.rename(folderName + '\\' + fileName, folderName + '\\' + fileName)
            else:
                print('It is over 1000!')

# %%
# ***UNIVERSAL*** create individual subdirectories for pages
import shutil, os
# insert absolute directory for volumes below
volsDir = input('Enter absolute directory of volumes: ')
os.chdir(volsDir)
volumes = 0
pages = 0
for folderName, subFolders, fileNames in os.walk(volsDir):
    if fileNames:
        print("Now renumbering images in " + folderName[folderName.rfind('\\') + 1:])
        for file in fileNames:
            if ('tif' in file) or ('JPG' in file) or ('jpg' in file):
                fileNum = int(file[:file.find('.')])
                ext = file[file.find('.'):]
                if fileNum < 10:
                    newNum = '000' + str(fileNum)
                elif fileNum < 100:
                    newNum = '00' + str(fileNum)
                elif fileNum < 1000:
                    newNum = '0' + str(fileNum)
                else:
                    newNum = str(fileNum)
                if(newNum + ext != file):
                    os.rename(folderName + '\\' + file, folderName + '\\' + newNum + ext)
for folderName, subFolders, fileNames in os.walk(volsDir):        
    if fileNames:
        print("Now nesting images in " + folderName[folderName.rfind('\\') + 1:])
        volumes += 1
        volPages = 0
        page = 1
        fileNames.sort()
        for fileName in fileNames:            
            if ('tif' in fileName) or ('JPG' in fileName) or ('jpg' in fileName):
                ext = fileName [fileName.find('.'):]                
                os.makedirs(folderName + '\\' + str(page))                                    
                shutil.move(folderName + '\\' + fileName, folderName + '\\' + str(page) + '\\OBJ' + ext)
                page += 1
                pages += 1
                volPages += 1               
            else:                
                #os.unlink(folderName + '\\' + fileName)
                print(folderName + '\\' + fileName + ' not deleted!')
        print(str(volPages) + " moved.")
print("Total volumes: " + str(volumes))
print("Total pages: " + str(pages))
# Out:
# Enter absolute directory of volumes: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\EAP627_ingest\AHP
# Now renumbering images in 0104
# Now renumbering images in 0125
# Now renumbering images in 0060
# Now renumbering images in 0088
# Now renumbering images in 0110
# Now renumbering images in 0009
# Now renumbering images in 0033
# Now renumbering images in 0075
# Now renumbering images in 0001
# Now renumbering images in 0013
# Now renumbering images in 0111
# Now renumbering images in 0096
# Now renumbering images in 0058
# Now renumbering images in 0127
# Now renumbering images in 0069
# Now renumbering images in 0007
# Now renumbering images in 0112
# Now renumbering images in 0041
# Now renumbering images in 0109
# Now renumbering images in 0084
# Now renumbering images in 0095
# Now renumbering images in 0039
# Now renumbering images in 0090
# Now renumbering images in 0073
# Now renumbering images in 0027
# Now renumbering images in 0047
# ...

# %%
# ***UNIVERSAL*** minimal metadata creator
import os
# insert absolute directory for volumes below
volsDir = input('Enter absolute directory of volumes: ')
os.chdir(volsDir)
volsWritten = 0
for folderName, subFolders, fileNames in os.walk(volsDir):
    if subFolders and (folderName != volsDir):
        os.chdir(folderName)
        title = folderName[folderName.rfind('\\') + 1:]
        print("Now writing minimal metadata for " + title)
        minMODS = open("MODS.xml","w",encoding='utf-8')
        minMODS.write("<mods xmlns=\"http://www.loc.gov/mods/v3\" xmlns:mods=\"http://www.loc.gov/mods/v3\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">")
        minMODS.write("<titleInfo>")                
        minMODS.write("<title>" + title + "</title>")
        minMODS.write("</titleInfo>")
        minMODS.write("</mods>")
        minMODS.close()
        volsWritten += 1    
print('Basic metadata written for ' + str(volsWritten) + ' volumes.')
# Out:
# Enter absolute directory of volumes: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\Angela\ESSS\digitalizacao Niteroi\Livros\Jacutinga\Jac_3
# Now writing minimal metadata for Jacutinga 003.1
# Basic metadata written for 1 volumes.

# %%
# ***UNIVERSAL*** create zip archive
import os, shutil
# insert absolute directory for volumes below
volsDir = input('Enter absolute directory of volumes: ')
os.chdir(volsDir)
dirName = volsDir[volsDir.rfind('\\') + 1:]
zipName = dirName + ' Batch'
print('Now zipping ' + dirName)
shutil.make_archive('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Zipped Batches\\' + zipName, 'zip')
print('Mission accomplished.')
# Out:
# Enter absolute directory of volumes: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\Angela\ESSS\digitalizacao Niteroi\Livros\Jacutinga\Jac_3
# Now zipping Jac_3
# Mission accomplished.

# %%
# ***UNIVERSAL*** all-in-one batch converter
# target directory should consist exclusively of sub-directories each containing the images of one volume
# image file names must be strictly integers but can be padded or unpadded
# valid image extensions are tif, JPG, and jpg
# files with any other extension in the target directory will be deleted
import shutil, os
volsDir = input('Enter absolute directory of volumes: ')
os.chdir(volsDir)
volumes = 0
pages = 0
for folderName, subFolders, fileNames in os.walk(volsDir):
    if fileNames:        
        print("Now renumbering images in " + folderName[folderName.rfind('\\') + 1:])
        for file in fileNames:
            if ('tif' in file) or ('JPG' in file) or ('jpg' in file):
                fileNum = int(file[:file.find('.')])
                ext = file[file.find('.'):]
                if fileNum < 10:
                    newNum = '000' + str(fileNum)
                elif fileNum < 100:
                    newNum = '00' + str(fileNum)
                elif fileNum < 1000:
                    newNum = '0' + str(fileNum)
                else:
                    newNum = str(fileNum)
                os.rename(folderName + '\\' + file, folderName + '\\' + newNum + ext)
for folderName, subFolders, fileNames in os.walk(volsDir):        
    if fileNames:
        print("Now nesting images in " + folderName[folderName.rfind('\\') + 1:])
        volumes += 1
        volPages = 0
        page = 1
        fileNames.sort()
        for fileName in fileNames:            
            if ('tif' in fileName) or ('JPG' in fileName) or ('jpg' in fileName):
                ext = fileName [fileName.find('.'):]                
                os.makedirs(folderName + '\\' + str(page))                                    
                shutil.move(folderName + '\\' + fileName, folderName + '\\' + str(page) + '\\OBJ' + ext)
                page += 1
                pages += 1
                volPages += 1               
            else:                
                os.unlink(folderName + '\\' + fileName)
                print(folderName + '\\' + fileName + ' deleted!')
        print(str(volPages) + " moved.")
print("Total volumes: " + str(volumes))
print("Total pages: " + str(pages))
volsWritten = 0
for folderName, subFolders, fileNames in os.walk(volsDir):
    if subFolders and (folderName != volsDir):
        os.chdir(folderName)
        title = folderName[folderName.rfind('\\') + 1:]
        print("Now writing minimal metadata for " + title)
        minMODS = open("MODS.xml","w",encoding='utf-8')
        minMODS.write("<mods xmlns=\"http://www.loc.gov/mods/v3\" xmlns:mods=\"http://www.loc.gov/mods/v3\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">")
        minMODS.write("<titleInfo>")                
        minMODS.write("<title>" + title + "</title>")
        minMODS.write("</titleInfo>")
        minMODS.write("</mods>")
        minMODS.close()
        volsWritten += 1    
print('Basic metadata written for ' + str(volsWritten) + ' volumes.')
os.chdir(volsDir)
dirName = volsDir[volsDir.rfind('\\') + 1:]
zipName = dirName + ' Batch'
print('Now zipping ' + dirName)
shutil.make_archive('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Zipped Batches\\' + zipName, 'zip')
print('Mission accomplished.')
# Out:
# Enter absolute directory of volumes: \\libshare.library.vanderbilt.edu\vulibrary\Landers\new_organization\Oscar\Iglesia San Juan Bautista S. Rafael y S. Vicente. Pueblo Nuevo. Matanzas
# Now renumbering images in Pueblo Nuevo Libro 3 Entierros P y M
# Now renumbering images in Pueblo Nuevo Libro 1 Bautismos P y M 1832-57
# Now renumbering images in Pueblo Nuevo Libro 2 Bautismos P y M 1841-53
# Now renumbering images in Pueblo Nuevo Libro 4 Bautismos P y M 1865-71
# Now renumbering images in Pueblo Nuevo Libro 2 Entierros P y M
# Now renumbering images in Pueblo Nuevo Libro 3 Bautismos P y M 1853-65
# Now renumbering images in Pueblo Nuevo Libro 5 Entierros P y M
# Now renumbering images in Pueblo Nuevo Libro 4 Entierros P y M
# Now renumbering images in Pueblo Nuevo Libro 1 Entierros P y M
# Now renumbering images in Pueblo Nuevo Libro 1 Matrimonios P y M
# Now renumbering images in Pueblo Nuevo Libro 6 Bautismos P y M 1885-93
# ...

# %%
#copy metadata records to batch directory
import os

os.chdir('C:\\Users\\genkindn')
MODScopied = 0
DCcopied = 0
for folderName, subFolders, fileNames in os.walk('St_Aug'):
    for fileName in fileNames:
        if 'St_Aug' in fileName:
            print('Now working on: ' + fileName)            
            number = str(int(fileName[-6:-4]))            
            volLoc = '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\st_augustine_10282013\\'
            if ('MODS' in fileName) and (os.path.exists(volLoc + number)):
                shutil.copy(folderName + '\\' + fileName,volLoc + number + '\\MODS.xml')
                print('MODS copied to ' + number)
                MODScopied += 1
            elif os.path.exists(volLoc + number):
                shutil.copy(folderName + '\\' + fileName,volLoc + number + '\\DC.xml')
                print('DC copied to ' + number)
                DCcopied += 1
print('MODS records copied: ' + str(MODScopied))
print('DC records copied: ' + str(DCcopied))
# Out:
# Now working on: St_Aug_DC_01.xml
# DC copied to 1
# Now working on: St_Aug_DC_02.xml
# DC copied to 2
# Now working on: St_Aug_DC_03.xml
# DC copied to 3
# Now working on: St_Aug_DC_04.xml
# DC copied to 4
# Now working on: St_Aug_DC_05.xml
# DC copied to 5
# Now working on: St_Aug_DC_06.xml
# DC copied to 6
# Now working on: St_Aug_DC_07.xml
# DC copied to 7
# Now working on: St_Aug_DC_08.xml
# DC copied to 8
# Now working on: St_Aug_DC_09.xml
# DC copied to 9
# Now working on: St_Aug_DC_10.xml
# DC copied to 10
# Now working on: St_Aug_DC_11.xml
# DC copied to 11
# Now working on: St_Aug_DC_12.xml
# DC copied to 12
# Now working on: St_Aug_DC_13.xml
# DC copied to 13
# Now working on: St_Aug_DC_14.xml
# DC copied to 14
# Now working on: St_Aug_DC_15.xml
# DC copied to 15
# Now working on: St_Aug_DC_16.xml
# DC copied to 16
# Now working on: St_Aug_DC_17.xml
# DC copied to 17
# Now working on: St_Aug_DC_18.xml
# DC copied to 18
# Now working on: St_Aug_DC_19.xml
# DC copied to 19
# ...

# %%
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization')

# %%
import os

broken_vol = '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Jacutinga\\Jacutinga 003.1'

page = 2

for folder, sub_folders, files in os.walk(broken_vol):
    files.sort()
    for file in files:
        if file.find('JPG') != -1:
            if page < 10:
                str_page = '00' + str(page)
            elif page < 100:
                str_page = '0' + str(page)
            else:
                str_page = str(page)            
            file_number = file[:file.find('.')]            
            if file_number == str_page:
                new_page = 1000 + page
                new_page_str = str(new_page)
                os.rename(file,broken_vol + '\\' + new_page_str + 'JPG')
                page += 11

# %%
import os

broken_vol = '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Jacutinga\\fuckme'

page = 1002

for folder, sub_folders, files in os.walk(broken_vol):
    files.sort()
    for file in files:
        page_str = str(page)
        page += 1
        #print(broken_vol + '\\' + file,broken_vol + '\\' + page_str + '.JPG')
        os.rename(broken_vol + '\\' + file,broken_vol + '\\' + page_str + '.JPG')

# %%
os.chdir('\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Jacutinga')

# %%
import os

start_seq = [1,112,223,334,445,556]
intermed_seq = [2,13,24,35,46,57,68,79,90,101,113,124,135,146,157,168,179,190,201,212,224,235,246,257,268,279,290,301,312,323,335,346,357,368,379,390,401,412,423,434,446,457,468,479,490,501,512,523,534,545,557,568,579,590,601]

correct_order = start_seq + intermed_seq

counter = 1

while counter <= 610:
    if counter not in correct_order:
        correct_order.append(counter)
    counter += 1



print(correct_order.index(1))
vol_dir = '\\\\libshare.library.vanderbilt.edu\\vulibrary\\Landers\\new_organization\\Angela\\ESSS\\digitalizacao Niteroi\\Livros\\Jacutinga\\Jacutinga 003.1'
for folder, sub_folders, files in os.walk(vol_dir):
    for file in files:
        if file.find('MODS') == -1:
            page_number = int(file[:file.find('.')])            
            correct_page = correct_order.index(page_number) + 1000
            os.rename(vol_dir + '\\' + file, vol_dir + '\\' + str(correct_page) + '.JPG')
# Out:
# 0
