# %%
master = open("Master.xml","r",encoding='utf-8')
activeVol = 1
for line in master:    
    if "<volume>" in line:
        writeDoc = open("Quibdo_" + str(activeVol) + ".xml","w",encoding='utf-8')        
        writeDoc.write("<oai_dc:dc xmlns:dc=\"http://purl.org/dc/elements/1.1/\" xmlns:oai_dc=\"http://www.openarchives.org/OAI/2.0/oai_dc/\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xsi:schemaLocation=\"http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd\">")        
    elif "</volume>" in line:      
        writeDoc.write("</oai_dc:dc>")
        writeDoc.close()
        activeVol += 1
    elif "<title>" in line:
        writeDoc.write(line)
        writeDoc.write("<creator>British Library EAP255</creator>")
        if activeVol < 25:
            writeDoc.write("<subject>Notarial records--Colombia--Early Modern</subject>")
        else:
            writeDoc.write("<subject>Notarial records--Colombia--Modern</subject>")
    elif "<description>" in line:     
        writeDoc.write(line)
        writeDoc.write("<publisher>Slave Societies Digital Archive</publisher>")
        writeDoc.write("<contributor>Pablo Gomez(project director)</contributor>")
        writeDoc.write("<contributor>Daniel Genkins(metadata creation)</contributor>")
    elif "<date>" in line:
        if " - " in line:
            sDay = line[8:10]
            sMon = line[10:14]            
            if sMon == "Jan":
                sMon = "01"
            elif sMon == "Feb":
                sMon = "02"
            elif sMon == "Mar":
                sMon = "03"
            elif sMon == "Apr":
                sMon = "04"
            elif sMon == "May":
                sMon = "05"
            elif sMon == "Jun":
                sMon = "06"
            elif sMon == "Jul":
                sMon = "07"
            elif sMon == "Aug":
                sMon = "08"
            elif sMon == "Sep":
                sMon = "09"
            elif sMon == "Oct":
                sMon = "10"
            elif sMon == "Nov":
                sMon = "11"
            else:
                sMon = "12"
            sYea = line[15:19]            
            eDay = line[22:24]            
            eMon = line[25:28]            
            if eMon == "Jan":
                eMon = "01"
            elif eMon == "Feb":
                eMon = "02"
            elif eMon == "Mar":
                eMon = "03"
            elif eMon == "Apr":
                eMon = "04"
            elif eMon == "May":
                eMon = "05"
            elif eMon == "Jun":
                eMon = "06"
            elif eMon == "Jul":
                eMon = "07"
            elif eMon == "Aug":
                eMon = "08"
            elif eMon == "Sep":
                eMon = "09"
            elif eMon == "Oct":
                eMon = "10"
            elif eMon == "Nov":
                eMon = "11"
            else:
                eMon = "12"
            eYea = line[29:33]            
            writeDoc.write("<date>" + sYea + "-" + sMon + "-" +sDay + "/" + eYea +"-" + eMon + "-" + eDay + "</date>")
        else:
            writeDoc.write(line)
        writeDoc.write("<type>Text</type>")
        writeDoc.write("<type>Notarial records</type>")
    elif "<format>" in line:
        writeDoc.write(line)
        writeDoc.write("<language>spa</language>")
    elif "<coverage>" in line:
        writeDoc.write(line)
        writeDoc.write("<coverage>Colombia</coverage>")
        writeDoc.write("<coverage>South America--Colombia--Chocó--Quibdó</coverage>")
        writeDoc.write("<coverage>5.68333,-76.65000</coverage>")
        if activeVol < 25:
            writeDoc.write("<coverage>Early Modern</coverage>")
        else:
            writeDoc.write("<coverage>Modern</coverage>")
        writeDoc.write("<rights>Vanderbilt University makes these historical records available for the limited purposes of individual private study, scholarship, research, teaching, and other educational or instructional uses. No rights of any kind are granted to users with respect to photographs or graphic images published on this site.</rights>")
    elif "<?xml" in line:
        print("First line.")
    elif "<volumes>" in line:
        print("Volumes initiated.")
    elif "</volumes>" in line:
        print("We did it!")
    else:        
        writeDoc.write(line)
master.close()
# Out:
# First line.
# Volumes initiated.
# We did it!

# %%
master = open("Master.xml","r",encoding='utf-8')
activeVol = 1
for line in master:    
    endStartTag = line.find(">")
    startEndTag = line.find("<",endStartTag)
    if "<volume>" in line:
        writeDoc = open("Quibdo_" + str(activeVol) + "_MODS.xml","w",encoding='utf-8')
        writeDoc.write("<mods xmlns=\"http://www.loc.gov/mods/v3\" xmlns:mods=\"http://www.loc.gov/mods/v3\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">")
        writeDoc.write("<titleInfo>")
    elif "<title>" in line:
        writeDoc.write(line)
        writeDoc.write("<subTitle/></titleInfo>")
        writeDoc.write("<name type=\"personal\"><namePart>Pablo Gomez</namePart><role><roleTerm authority=\"marcrelator\" type=\"text\">Project Director</roleTerm></role></name>")
        writeDoc.write("<name type=\"personal\"><namePart>Daniel Genkins</namePart><role><roleTerm authority=\"marcrelator\" type=\"text\">Metadata Creation</roleTerm></role></name>")
        writeDoc.write("<typeOfResource>text</typeOfResource>")
        writeDoc.write("<genre authority=\"marcgt\" />")
        writeDoc.write("<tableOfContents/>")
        writeDoc.write("<originInfo><dateIssued></dateIssued><copyrightDate/><issuance>monographic</issuance><edition/><publisher/><place/></originInfo>")
        writeDoc.write("<language><languageTerm authority=\"iso639-2b\" type=\"code\">spa</languageTerm></language>")
    elif "<date>" in line:
        date = line[endStartTag + 1:startEndTag]
    elif "<description>" in line:        
        writeDoc.write("<abstract>" + line[endStartTag + 1:startEndTag] + "</abstract>")
        writeDoc.write("<identifier type=\"isbn\"/>")
    elif "<format>" in line:        
        writeDoc.write("<physicalDescription><form>" + line[endStartTag + 1:startEndTag] + "</form><extent/></physicalDescription>")
        writeDoc.write("<note/>")
    elif "<coverage>" in line:        
        writeDoc.write("<subject><topic/><geographic>" + line[endStartTag + 1:startEndTag] + "</geographic><temporal>" + date + "</temporal>")
        writeDoc.write("<hierarchicalGeographic><continent>South America</continent><country>Colombia></country><province>Chocó</province><region/><county/><city>Quibdó</city><citySection/></hierarchicalGeographic>")
        writeDoc.write("<cartographics><coordinates>5.68333, -76.65000</coordinates></cartographics></subject>")
        writeDoc.write("<classification/>")
        writeDoc.write("<name/>")
    elif "</volume>" in line:      
        writeDoc.write("</mods>")
        writeDoc.close()
        activeVol += 1
    elif "<?xml" in line:
        print("First line.")
    elif "<volumes>" in line:
        print("Volumes initiated.")
    elif "</volumes>" in line:
        print("We did it!")
    else:
        writeDoc.write("Found something weird.")
master.close()
# Out:
# First line.
# Volumes initiated.
# We did it!

# %%
import os

os.chdir('C:\\Users\\genkindn\\St_Aug')
master = open("DC_Master.xml","r",encoding='utf-8')
activeVol = 1
for line in master:
    if "<volume>" in line:
        if activeVol >= 10:
            writeDoc = open("St_Aug_DC_" + str(activeVol) + ".xml","w",encoding='utf-8')
        else:
            writeDoc = open("St_Aug_DC_0" + str(activeVol) + ".xml","w",encoding='utf-8')
        writeDoc.write("<oai_dc:dc xmlns:dc=\"http://purl.org/dc/elements/1.1/\" xmlns:oai_dc=\"http://www.openarchives.org/OAI/2.0/oai_dc/\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xsi:schemaLocation=\"http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd\">")        
    elif "</volume>" in line:
        writeDoc.write("</oai_dc:dc>")
        writeDoc.close()
        activeVol += 1
    elif "<title>" in line:
        writeDoc.write(line)
        writeDoc.write("<creator>Digitization  of the Archives of the Diocese of St. Augustine (DADS)</creator>")
        writeDoc.write("<subject>")
        if 'Baptisms' in line:
            writeDoc.write('Baptisms--')
        if ('Burials' in line) or ('Deaths' in line):
            writeDoc.write('Burials--')
        if 'Marriages' in line:
            writeDoc.write('Marriages--')
        if 'Confirmations' in line:
            writeDoc.write('Confirmations--')
        if (activeVol == 14) or (activeVol == 15) or (activeVol == 30):
            writeDoc.write('Baptisms--Marriages--')
        writeDoc.write('Spanish Florida--Early Modern</subject>')
    elif "<description>" in line:     
        writeDoc.write(line)
        writeDoc.write("<publisher>Slave Societies Digital Archive</publisher>")
        writeDoc.write("<contributor>Jane Landers(project director)</contributor>")
        writeDoc.write("<contributor>Daniel Genkins(metadata creation)</contributor>")
    elif "<date>" in line:
        writeDoc.write(line)
        writeDoc.write("<type>Text</type>")
        writeDoc.write("<type>Ecclesiastical records</type>")
    elif "<format>" in line:
        writeDoc.write(line)
    elif "<language>" in line:
        writeDoc.write(line)    
        writeDoc.write("<coverage>Archives of the Diocese of St. Augustine, St. Augustine, Florida, United States</coverage>")
        writeDoc.write("<coverage>Spanish Florida</coverage>")
        writeDoc.write("<coverage>North America--United States--Florida--St. Augustine</coverage>")
        writeDoc.write("<coverage>29.89472,-81.31444</coverage>")        
        writeDoc.write("<coverage>Early Modern</coverage>")        
        writeDoc.write("<rights>Vanderbilt University makes these historical records available for the limited purposes of individual private study, scholarship, research, teaching, and other educational or instructional uses. No rights of any kind are granted to users with respect to photographs or graphic images published on this site.</rights>")
    elif "<?xml" in line:
        print("First line.")
    elif "<volumes>" in line:
        print("Volumes initiated.")
    elif "</volumes>" in line:
        print("We did it!")
    else:        
        writeDoc.write(line)
master.close()
# Out:
# First line.
# Volumes initiated.
# We did it!

# %%
import os

os.chdir('C:\\Users\\genkindn\\St_Aug')
master = open("Master.xml","r",encoding='utf-8')
activeVol = 1
for line in master:    
    endStartTag = line.find(">")
    startEndTag = line.find("<",endStartTag)
    if "<volume>" in line:
        if activeVol >= 10:
            writeDoc = open("St_Aug_MODS_" + str(activeVol) + ".xml","w",encoding='utf-8')
        else:
            writeDoc = open("St_Aug_MODS_0" + str(activeVol) + ".xml","w",encoding='utf-8')
        writeDoc.write("<mods xmlns=\"http://www.loc.gov/mods/v3\" xmlns:mods=\"http://www.loc.gov/mods/v3\" xmlns:xsi=\"http://www.w3.org/2001/XMLSchema-instance\" xmlns:xlink=\"http://www.w3.org/1999/xlink\">")
        writeDoc.write("<titleInfo>")
    elif "<title>" in line:
        writeDoc.write(line)
        writeDoc.write("<subTitle/></titleInfo>")
        writeDoc.write("<name type=\"personal\"><namePart>Jane Landers</namePart><role><roleTerm authority=\"marcrelator\" type=\"text\">Project Director</roleTerm></role></name>")
        writeDoc.write("<name type=\"personal\"><namePart>Daniel Genkins</namePart><role><roleTerm authority=\"marcrelator\" type=\"text\">Metadata Creation</roleTerm></role></name>")
        writeDoc.write("<typeOfResource>text</typeOfResource>")
        writeDoc.write("<genre authority=\"marcgt\" />")
        writeDoc.write("<tableOfContents/>")
        writeDoc.write("<originInfo><dateIssued></dateIssued><copyrightDate/><issuance>monographic</issuance><edition/><publisher/><place/></originInfo>")
    elif "<language>" in line:
        writeDoc.write("<language><languageTerm authority=\"iso639-2b\" type=\"code\">" + line[endStartTag + 1:startEndTag] + "</languageTerm></language>")     
    elif "<date>" in line:
        date = line[endStartTag + 1:startEndTag]
    elif "<description>" in line:        
        writeDoc.write("<abstract>" + line[endStartTag + 1:startEndTag] + "</abstract>")
        writeDoc.write("<identifier type=\"isbn\"/>")
    elif "<format>" in line:        
        writeDoc.write("<physicalDescription><form>" + line[endStartTag + 1:startEndTag] + "</form><extent/></physicalDescription>")
        writeDoc.write("<note/>")            
        writeDoc.write("<subject><topic/><geographic>Archives of the Diocese of St. Augustine, St. Augustine, Florida, United States</geographic><temporal>" + date + "</temporal>")
        writeDoc.write("<hierarchicalGeographic><continent>North America</continent><country>United States</country><province>Florida</province><region/><county/><city>St. Augustine</city><citySection/></hierarchicalGeographic>")
        writeDoc.write("<cartographics><coordinates>29.89472,-81.31444</coordinates></cartographics></subject>")
        writeDoc.write("<classification/>")
        writeDoc.write("<name/>")
    elif "</volume>" in line:      
        writeDoc.write("</mods>")
        writeDoc.close()
        activeVol += 1
    elif "<?xml" in line:
        print("First line.")
    elif "<volumes>" in line:
        print("Volumes initiated.")
    elif "</volumes>" in line:
        print("We did it!")
    else:
        writeDoc.write("Found something weird.")
master.close()
# Out:
# First line.
# Volumes initiated.
# We did it!
